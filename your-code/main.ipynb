# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
import sqlalchemy
import pandas as pd

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
ax1 = sns.boxplot(x=x, y=z, color='.25', linewidth=4.5)
ax2 = sns.boxplot(x=x, y=y, color='.25', linewidth=4.5)
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
ax2.set_xticklabels(ax2.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8'),
#  Text(0, 0, '9'),
#  Text(0, 0, '10'),
#  Text(0, 0, '11'),
#  Text(0, 0, '12'),
#  Text(0, 0, '13'),
#  Text(0, 0, '14'),
#  Text(0, 0, '15'),
#  Text(0, 0, '16'),
#  Text(0, 0, '17'),
#  Text(0, 0, '18'),
#  Text(0, 0, '19'),
#  Text(0, 0, '20'),
#  Text(0, 0, '21'),
#  Text(0, 0, '22'),
#  Text(0, 0, '23'),
#  Text(0, 0, '24'),
#  Text(0, 0, '25'),
#  Text(0, 0, '26'),
#  Text(0, 0, '27'),
#  Text(0, 0, '28'),
#  Text(0, 0, '29'),
#  Text(0, 0, '30'),
#  Text(0, 0, '31'),
#  Text(0, 0, '32'),
#  Text(0, 0, '33'),
#  Text(0, 0, '34'),
#  Text(0, 0, '35'),
#  Text(0, 0, '36'),
#  Text(0, 0, '37'),
#  Text(0, 0, '38'),
#  Text(0, 0, '39'),
#  Text(0, 0, '40'),
#  Text(0, 0, '41'),
#  Text(0, 0, '42'),
#  Text(0, 0, '43'),
#  Text(0, 0, '44'),
#  Text(0, 0, '45'),
#  Text(0, 0, '46'),
#  Text(0, 0, '47'),
# ...

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
fig, [ax1, ax2] = plt.subplots(1,2)
ax1.plot(x,z) 
ax2.plot(x,y)

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, [ax1, ax2] = plt.subplots(1,2,figsize=(15,15))
ax1.plot(x,z)
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')   

ax2.plot(x,y)
ax2.set_xlabel('x label')
ax2.set_ylabel('y label')

plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
x = np.arange(0,100)
y1 = x**2
y2 = np.exp(x)


f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 8))
ax1.plot(x, y1, color='red', linewidth=3)
ax1.legend("x",loc="upper left")
ax1.set_xscale('linear')
ax1.set_yscale('linear')
ax1.set_title('x vs. x^2', fontsize=18, fontweight='bold', color='red', style='italic')
ax1.set_xlabel('x', fontsize=18, fontweight='bold', color='red')
ax1.set_ylabel('x^2', fontsize=18, fontweight='bold', color='red')
ax1.grid(True)
ax2.plot(x, y2, color='blue', linewidth=3)
ax2.legend("x",loc="upper left")
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_title('x vs. e^x', fontsize=18, fontweight='bold', color='blue', style='italic')
ax2.set_xlabel('x', fontsize=18, fontweight='bold', color='blue')
ax2.set_ylabel('e^x', fontsize=18, fontweight='bold', color='blue')
ax2.grid(True)

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %% [markdown]
# See above

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
import sqlalchemy
import pandas as pd
conn_string = 'mysql+pymysql://root:&FK^[8jLK$"/4=n*@34.65.10.136:3306/fitbit'
conn = sqlalchemy.create_engine(conn_string)
fitbit = pd.read_sql_query('SELECT * FROM fitbit2', conn)

# %%
fitbit.head()
# Out:
#          Date  Calorie burned  Steps Distance  Floors Minutes Sedentary  \
# 0  2015-05-08            1934    905     0.65       0             1.355
# 1  2015-05-09            3631  18925    14.11       4               611
# 2  2015-05-10            3204  14228    10.57       1               602
# 3  2015-05-11            2673   6756     5.02       8               749
# 4  2015-05-12            2495    502     3.73       1               876
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
steps_months_encoded = fitbit[['Steps','Months_encoded']].groupby('Months_encoded').median()
f, (ax1) = plt.subplots(1, 1, figsize=(12, 4))
ax1.plot(steps_months_encoded,color='red', linewidth=3)
ax1.legend("Steps",loc="upper left")
ax1.set_xscale('linear')
ax1.set_yscale('linear')
ax1.set_title('x vs. x^2', fontsize=18, fontweight='bold', color='red', style='italic')
ax1.set_xlabel('x', fontsize=18, fontweight='bold', color='red')
ax1.set_ylabel('x^2', fontsize=18, fontweight='bold', color='red')
ax1.grid(True)

# WEEK or WEEKENd
steps_week_weekend = fitbit[['Steps','Work_or_Weekend']].groupby('Work_or_Weekend').mean()
steps_week_weekend.plot(kind = 'bar', alpha = 0.8, color='red')
ax2.legend("x",loc="upper left")
ax2.set_title('x vs. e^x', fontsize=18, fontweight='bold', color='blue', style='italic')
ax2.set_xlabel('x', fontsize=18, fontweight='bold', color='blue')
ax2.set_ylabel('e^x', fontsize=18, fontweight='bold', color='blue')
# Out:
# Text(406.0613636363635, 0.5, 'e^x')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
minutes = (fitbit['Minutes Lightly Active'], fitbit['Minutes Very Active'], fitbit['Minutes Sedentary'])
y = fitbit['Steps']
for m in minutes:
    plt.scatter(m,y)
plt.xlabel('Steps')
plt.ylabel('Minutes')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
conn_string = 'mysql+pymysql://root:&FK^[8jLK$"/4=n*@34.65.10.136:3306/titanic'
conn = sqlalchemy.create_engine(conn_string)
titanic = pd.read_sql_query('SELECT * FROM titanic', conn)

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes('number').head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes('object').head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).**Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
plt.rcParams['figure.figsize'] = [12,6]
titanic.plot()

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
titanic_age = titanic['Age'].hist(bins=20)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
plt.sca(ax1)
titanic['Age'].hist(bins=10)
plt.title('10 bins')
plt.sca(ax2)
titanic['Age'].hist(bins=20)
plt.title('20 bins')
plt.sca(ax3)
titanic['Age'].hist(bins=50)
plt.title('50 bins')
# Out:
# Text(0.5, 1.0, '50 bins')

# %% [markdown]
# #### How does the bin size affect your plot?

# %% [markdown]
# The bin size does affect on how detailed the information looks. The more the number of bins, the more detailed you see on the number of elements per age.

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.distplot(titanic['Age'])

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
tit_gen = titanic['Gender'].value_counts()
labels = ['Male', 'Female']
sizes = [tit_gen[0],tit_gen[1]]
explode = (0, 0.1)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')
plt.show()

# %%
# Method 2 - seaborn
sns.countplot(x='Gender', data=titanic)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x='Pclass', data=titanic)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
plt.style.use('classic')
plt.rcParams['figure.figsize'] = [12,6]
titanic['Age'].plot()

# %% [markdown]
#  Age has many attributes and variables related to it with different behaviour

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
All the ages move around a value of 30.

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
fig, ax = plt.subplots()
ax.hist(titanic.Age, bins = 50)
plt.figtext(0.75,0.5, titanic.Age.describe().to_string())
# Out:
# Text(0.75, 0.5, 'count    1309.000000\nmean       29.879186\nstd        13.448335\nmin         0.170000\n25%        22.000000\n50%        28.500000\n75%        37.000000\nmax        80.000000')

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %% [markdown]
# It gives you more detals about the distribution of age. Which are the more common ages, the distribution in different ages and how spread those ages are. You can also find some extreme values.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
age_fare = titanic[['Age','Fare']]
age_fare = age_fare.astype('int32')
fig, ax = plt.subplots()
ax.plot(age_fare)

# %%
# Method 2 - seaborn
ax1 = sns.boxplot(x=age_fare['Age'], y=age_fare['Fare'], color='.25', linewidth=2)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr = age_fare[['Age','Fare']].corr()
ax = sns.heatmap(
    corr,
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(0, 0, n=5), #n= is just the number of steps
    #cmap=sns.diverging_palette(80, 200, n=200), 
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
# Out:
# [Text(0.5, 0, 'Age'), Text(1.5, 0, 'Fare')]

# %% [markdown]
# #### What are the most correlated features?

# %%
titanic.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.boxplot(x='Pclass', y='Age', hue=None, data=titanic, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, notch=False, ax=None)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sns.FacetGrid(titanic, col='Gender').map(plt.hist,'Age')
